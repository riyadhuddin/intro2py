# %% [markdown]
# <b> Imagine in the year 2051, BD will conduct its first inter galaxy exploratory mission. 11 Cute potentials will follow and supervise this mission. Due to expensive earthly responses, sustainability remains the main course of humans. So it is decided that they are going to enjoy not only extreme behavior of foreign but many more and self reasoning is the only path. Of course, they may have few sophisticated artificial presences to determine mission-critical and maintain liveliness.
#
# Can we help them to generate such capable solutions maintaining durability and flexibility?

# %% [markdown]
# # Lets start with Orbit Transfer and Trajectories
# 1. Hohmann Transfer

# %%
from PIL import Image
import requests
url = "https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Hohmann_transfer_orbit2.svg/800px-Hohmann_transfer_orbit2.svg.png"
im = Image.open(requests.get(url, stream=True).raw)
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x800 at 0x1C8D524C430>
